# %%
"""Synthesizes speech from the input string of text or ssml.
Make sure to be working in a virtual environment.

Note: ssml must be well-formed according to:
    https://www.w3.org/TR/speech-synthesis/
"""
from google.cloud import texttospeech

# Instantiates a client
client = texttospeech.TextToSpeechClient()

# Set the text input to be synthesized
synthesis_input = texttospeech.SynthesisInput(text="Hello, World!")

# Build the voice request, select the language code ("en-US") and the ssml
# voice gender ("neutral")
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
)

# Select the type of audio file you want returned
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
)

# Perform the text-to-speech request on the text input with the selected
# voice parameters and audio file type
response = client.synthesize_speech(
    input=synthesis_input, voice=voice, audio_config=audio_config
)

# The response's audio_content is binary.
with open("output.mp3", "wb") as out:
    # Write the response to the output file.
    out.write(response.audio_content)
    print('Audio content written to file "output.mp3"')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:3037, in DistInfoDistribution._dep_map(self)
#    3036 try:
# -> 3037     return self.__dep_map
#    3038 except AttributeError:
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:2834, in Distribution.__getattr__(self, attr)
#    2833 if attr.startswith('_'):
# -> 2834     raise AttributeError(attr)
#    2835 return getattr(self._provider, attr)
#
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:3028, in DistInfoDistribution._parsed_pkg_info(self)
#    3027 try:
# -> 3028     return self._pkg_info
#    3029 except AttributeError:
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:2834, in Distribution.__getattr__(self, attr)
#    2833 if attr.startswith('_'):
# -> 2834     raise AttributeError(attr)
#    2835 return getattr(self._provider, attr)
#
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 7
#       1 """Synthesizes speech from the input string of text or ssml.
#       2 Make sure to be working in a virtual environment.
#       3
#       4 Note: ssml must be well-formed according to:
#       5     https://www.w3.org/TR/speech-synthesis/
#       6 """
# ----> 7 from google.cloud import texttospeech
#       9 # Instantiates a client
#      10 client = texttospeech.TextToSpeechClient()
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech\__init__.py:17
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2022 Google LLC
#       3 #
#    (...)
#      14 # limitations under the License.
#      15 #
# ---> 17 from google.cloud.texttospeech_v1.services.text_to_speech.async_client import (
#      18     TextToSpeechAsyncClient,
#      19 )
#      20 from google.cloud.texttospeech_v1.services.text_to_speech.client import (
#      21     TextToSpeechClient,
#      22 )
#      23 from google.cloud.texttospeech_v1.types.cloud_tts import (
#      24     AudioConfig,
#      25     AudioEncoding,
#    (...)
#      34     VoiceSelectionParams,
#      35 )
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech_v1\__init__.py:17
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2022 Google LLC
#       3 #
#    (...)
#      14 # limitations under the License.
#      15 #
# ---> 17 from .services.text_to_speech import TextToSpeechAsyncClient, TextToSpeechClient
#      18 from .types.cloud_tts import (
#      19     AudioConfig,
#      20     AudioEncoding,
#    (...)
#      29     VoiceSelectionParams,
#      30 )
#      32 __all__ = (
#      33     "TextToSpeechAsyncClient",
#      34     "AudioConfig",
#    (...)
#      45     "VoiceSelectionParams",
#      46 )
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\__init__.py:16
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2022 Google LLC
#       3 #
#    (...)
#      14 # limitations under the License.
#      15 #
# ---> 16 from .async_client import TextToSpeechAsyncClient
#      17 from .client import TextToSpeechClient
#      19 __all__ = (
#      20     "TextToSpeechClient",
#      21     "TextToSpeechAsyncClient",
#      22 )
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\async_client.py:36
#      32     OptionalRetry = Union[retries.Retry, object]  # type: ignore
#      34 from google.cloud.texttospeech_v1.types import cloud_tts
# ---> 36 from .client import TextToSpeechClient
#      37 from .transports.base import DEFAULT_CLIENT_INFO, TextToSpeechTransport
#      38 from .transports.grpc_asyncio import TextToSpeechGrpcAsyncIOTransport
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\client.py:39
#      35     OptionalRetry = Union[retries.Retry, object]  # type: ignore
#      37 from google.cloud.texttospeech_v1.types import cloud_tts
# ---> 39 from .transports.base import DEFAULT_CLIENT_INFO, TextToSpeechTransport
#      40 from .transports.grpc import TextToSpeechGrpcTransport
#      41 from .transports.grpc_asyncio import TextToSpeechGrpcAsyncIOTransport
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\__init__.py:19
#      16 from collections import OrderedDict
#      17 from typing import Dict, Type
# ---> 19 from .base import TextToSpeechTransport
#      20 from .grpc import TextToSpeechGrpcTransport
#      21 from .grpc_asyncio import TextToSpeechGrpcAsyncIOTransport
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\base.py:32
#      28 from google.cloud.texttospeech_v1.types import cloud_tts
#      30 try:
#      31     DEFAULT_CLIENT_INFO = gapic_v1.client_info.ClientInfo(
# ---> 32         gapic_version=pkg_resources.get_distribution(
#      33             "google-cloud-texttospeech",
#      34         ).version,
#      35     )
#      36 except pkg_resources.DistributionNotFound:
#      37     DEFAULT_CLIENT_INFO = gapic_v1.client_info.ClientInfo()
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:478, in get_distribution(dist)
#     476     dist = Requirement.parse(dist)
#     477 if isinstance(dist, Requirement):
# --> 478     dist = get_provider(dist)
#     479 if not isinstance(dist, Distribution):
#     480     raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:354, in get_provider(moduleOrReq)
#     352 """Return an IResourceProvider for the named module or requirement"""
#     353 if isinstance(moduleOrReq, Requirement):
# --> 354     return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     355 try:
#     356     module = sys.modules[moduleOrReq]
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:909, in WorkingSet.require(self, *requirements)
#     900 def require(self, *requirements):
#     901     """Ensure that distributions matching `requirements` are activated
#     902
#     903     `requirements` must be a string or a (possibly-nested) sequence
#    (...)
#     907     included, even if they were already activated in this working set.
#     908     """
# --> 909     needed = self.resolve(parse_requirements(requirements))
#     911     for dist in needed:
#     912         self.add(dist)
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:803, in WorkingSet.resolve(self, requirements, env, installer, replace_conflicting, extras)
#     800     raise VersionConflict(dist, req).with_context(dependent_req)
#     802 # push the new requirements onto the stack
# --> 803 new_requirements = dist.requires(req.extras)[::-1]
#     804 requirements.extend(new_requirements)
#     806 # Register the new requirements needed by req
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:2755, in Distribution.requires(self, extras)
#    2753 def requires(self, extras=()):
#    2754     """List of Requirements needed for this distro if `extras` are used"""
# -> 2755     dm = self._dep_map
#    2756     deps = []
#    2757     deps.extend(dm.get(None, ()))
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:3039, in DistInfoDistribution._dep_map(self)
#    3037     return self.__dep_map
#    3038 except AttributeError:
# -> 3039     self.__dep_map = self._compute_dependencies()
#    3040     return self.__dep_map
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:3048, in DistInfoDistribution._compute_dependencies(self)
#    3046 reqs = []
#    3047 # Including any condition expressions
# -> 3048 for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#    3049     reqs.extend(parse_requirements(req))
#    3051 def reqs_for_extra(extra):
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:3030, in DistInfoDistribution._parsed_pkg_info(self)
#    3028     return self._pkg_info
#    3029 except AttributeError:
# -> 3030     metadata = self.get_metadata(self.PKG_INFO)
#    3031     self._pkg_info = email.parser.Parser().parsestr(metadata)
#    3032     return self._pkg_info
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:1431, in NullProvider.get_metadata(self, name)
#    1429     return ""
#    1430 path = self._get_metadata_path(name)
# -> 1431 value = self._get(path)
#    1432 try:
#    1433     return value.decode('utf-8')
#
# File ~\anaconda3\envs\rasa\lib\site-packages\pkg_resources\__init__.py:1635, in DefaultProvider._get(self, path)
#    1634 def _get(self, path):
# -> 1635     with open(path, 'rb') as stream:
#    1636         return stream.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\users\\user\\anaconda3\\envs\\rasa\\lib\\site-packages\\protobuf-3.19.6.dist-info\\METADATA'

# %%
##Google Speech-To-Text API Tutorial with Python

# %%
from google.cloud import speech
import os
import io


#setting Google credential
os.environ['GOOGLE_APPLICATION_CREDENTIALS']= 'google_secret_key.json'
# create client instance 
client = speech.SpeechClient()
#the path of your audio file
file_name = "C:\\Users\\user\\Desktop\\welcome.mp3"
with io.open(file_name, "rb") as audio_file:
    content = audio_file.read()
    audio = speech.RecognitionAudio(content=content)
    
# the configuration for the speech-to-text engine    
config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    enable_automatic_punctuation=True,
    audio_channel_count=2,
    language_code="en-US",
)

# Sends the request to google to transcribe the audio
response = client.recognize(request={"config": config, "audio": audio})
# Reads the response
for result in response.results:
    print("Transcript: {}".format(result.alternatives[0].transcript))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 from google.cloud import speech
#       2 import os
#       3 import io
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\speech.py:20
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Copyright 2020 Google LLC
#    (...)
#      14 # See the License for the specific language governing permissions and
#      15 # limitations under the License.
#      18 from __future__ import absolute_import
# ---> 20 from google.cloud.speech_v1 import SpeechClient
#      21 from google.cloud.speech_v1 import enums
#      22 from google.cloud.speech_v1 import types
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\speech_v1\__init__.py:17
#       1 # Copyright 2017 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from __future__ import absolute_import
# ---> 17 from google.cloud.speech_v1.gapic import speech_client
#      18 from google.cloud.speech_v1.gapic import enums
#      20 from google.cloud.speech_v1.helpers import SpeechHelpers
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\speech_v1\gapic\speech_client.py:35
#      33 from google.cloud.speech_v1.gapic import enums
#      34 from google.cloud.speech_v1.gapic import speech_client_config
# ---> 35 from google.cloud.speech_v1.gapic.transports import speech_grpc_transport
#      36 from google.cloud.speech_v1.proto import cloud_speech_pb2
#      37 from google.cloud.speech_v1.proto import cloud_speech_pb2_grpc
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\speech_v1\gapic\transports\speech_grpc_transport.py:21
#      18 import google.api_core.grpc_helpers
#      19 import google.api_core.operations_v1
# ---> 21 from google.cloud.speech_v1.proto import cloud_speech_pb2_grpc
#      24 class SpeechGrpcTransport(object):
#      25     """gRPC transport class providing stubs for
#      26     google.cloud.speech.v1 Speech API.
#      27
#    (...)
#      30     features of gRPC.
#      31     """
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\speech_v1\proto\cloud_speech_pb2_grpc.py:4
#       1 # Generated by the gRPC Python protocol compiler plugin. DO NOT EDIT!
#       2 import grpc
# ----> 4 from google.cloud.speech_v1.proto import (
#       5     cloud_speech_pb2 as google_dot_cloud_dot_speech__v1_dot_proto_dot_cloud__speech__pb2,
#       6 )
#       7 from google.longrunning import (
#       8     operations_pb2 as google_dot_longrunning_dot_operations__pb2,
#       9 )
#      12 class SpeechStub(object):
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\cloud\speech_v1\proto\cloud_speech_pb2.py:59
#      27 from google.rpc import status_pb2 as google_dot_rpc_dot_status__pb2
#      30 DESCRIPTOR = _descriptor.FileDescriptor(
#      31     name="google/cloud/speech_v1/proto/cloud_speech.proto",
#      32     package="google.cloud.speech.v1",
#    (...)
#      49     ],
#      50 )
#      53 _RECOGNITIONCONFIG_AUDIOENCODING = _descriptor.EnumDescriptor(
#      54     name="AudioEncoding",
#      55     full_name="google.cloud.speech.v1.RecognitionConfig.AudioEncoding",
#      56     filename=None,
#      57     file=DESCRIPTOR,
#      58     values=[
# ---> 59         _descriptor.EnumValueDescriptor(
#      60             name="ENCODING_UNSPECIFIED",
#      61             index=0,
#      62             number=0,
#      63             serialized_options=None,
#      64             type=None,
#      65         ),
#      66         _descriptor.EnumValueDescriptor(
#      67             name="LINEAR16", index=1, number=1, serialized_options=None, type=None
#      68         ),
#      69         _descriptor.EnumValueDescriptor(
#      70             name="FLAC", index=2, number=2, serialized_options=None, type=None
#      71         ),
#      72         _descriptor.EnumValueDescriptor(
#      73             name="MULAW", index=3, number=3, serialized_options=None, type=None
#      74         ),
#      75         _descriptor.EnumValueDescriptor(
#      76             name="AMR", index=4, number=4, serialized_options=None, type=None
#      77         ),
#      78         _descriptor.EnumValueDescriptor(
#      79             name="AMR_WB", index=5, number=5, serialized_options=None, type=None
#      80         ),
#      81         _descriptor.EnumValueDescriptor(
#      82             name="OGG_OPUS", index=6, number=6, serialized_options=None, type=None
#      83         ),
#      84         _descriptor.EnumValueDescriptor(
#      85             name="SPEEX_WITH_HEADER_BYTE",
#      86             index=7,
#      87             number=7,
#      88             serialized_options=None,
#      89             type=None,
#      90         ),
#      91     ],
#      92     containing_type=None,
#      93     serialized_options=None,
#      94     serialized_start=1521,
#      95     serialized_end=1660,
#      96 )
#      97 _sym_db.RegisterEnumDescriptor(_RECOGNITIONCONFIG_AUDIOENCODING)
#      99 _RECOGNITIONMETADATA_INTERACTIONTYPE = _descriptor.EnumDescriptor(
#     100     name="InteractionType",
#     101     full_name="google.cloud.speech.v1.RecognitionMetadata.InteractionType",
#    (...)
#     144     serialized_end=2517,
#     145 )
#
# File ~\anaconda3\envs\rasa\lib\site-packages\google\protobuf\descriptor.py:755, in __new__(cls, name, index, number, type, options, serialized_options, create_key)
#     748   def __new__(cls, name, index, number,
#     749               type=None,  # pylint: disable=redefined-builtin
#     750               options=None, serialized_options=None, create_key=None):
#     751     _message.Message._CheckCalledFromGeneratedFile()
#     752     # There is no way we can build a complete EnumValueDescriptor with the
#     753     # given parameters (the name of the Enum is not known, for example).
#     754     # Fortunately generated files just pass it to the EnumDescriptor()
# --> 755     # constructor, which will ignore it, so returning None is good enough.
#     756     return None
#     758 def __init__(self, name, index, number,
#     759              type=None,  # pylint: disable=redefined-builtin
#     760              options=None, serialized_options=None, create_key=None):
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
#!python -m pip install google-cloud-speech==1.3.2
